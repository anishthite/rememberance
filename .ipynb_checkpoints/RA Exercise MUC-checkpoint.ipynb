# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
plt.rcParams["figure.figsize"] = (7,3)
plt.rcParams['axes.facecolor'] = 'white'

# %%
#remove first 5 responses
df = pd.read_csv('EXERCISE Head Worn Displays Quiz Student Analysis Report.csv')[5:]
df2 = pd.read_csv('EXERCISE Head Worn Displays 2 Quiz Student Analysis Report.csv')

# %%
#remove bad columns
df = df.drop([x for i, x in enumerate(df.columns) if i % 2 == 1], axis=1)
df = df.drop(['Unnamed: 0', 'Unnamed: 14', 'n correct', 'score'], axis=1)
df2 = df2.drop([x for i, x in enumerate(df2.columns) if i % 2 == 1], axis=1)
df2 = df2.drop([df2.columns[7], df2.columns[0], 'n correct', 'score'], axis=1)

# %%
df2
# Out:
#    8679193: Student CenterVideo: The interviewee made sufficient eye contact  \
# 0                                            6. Agree
# 1                                3. Somewhat Disagree
# 2                                         2. Disagree
# 3                                   5. Somewhat Agree
# 4                                            6. Agree
# ..                                                ...
# 57                                           6. Agree
# 58                                           6. Agree
# 59                                  7. Strongly Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679183: Student CenterVideo: The interviewee gave specific and detailed answers  \
# 0                                   5. Somewhat Agree
# 1                                   5. Somewhat Agree
# 2                                   7. Strongly Agree
# 3                                          4. Neutral
# 4                                            6. Agree
# ..                                                ...
# 57                                  7. Strongly Agree
# 58                                           6. Agree
# 59                                  7. Strongly Agree
# 60                                  7. Strongly Agree
# 61                                           6. Agree
#
#    8679185: Student CenterVideo: The interviewee's answers were relevant and non-contradictory  \
# 0                                            6. Agree
# 1                                         2. Disagree
# 2                                            6. Agree
# 3                                3. Somewhat Disagree
# 4                                   5. Somewhat Agree
# ..                                                ...
# 57                                  7. Strongly Agree
# 58                                  5. Somewhat Agree
# 59                                  7. Strongly Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679187: Student CenterVideo: The interviewee was engaged in the conversation  \
# 0                                            6. Agree
# 1                                   5. Somewhat Agree
# 2                                   5. Somewhat Agree
# 3                                   5. Somewhat Agree
# 4                                   5. Somewhat Agree
# ..                                                ...
# 57                                           6. Agree
# 58                                           6. Agree
# 59                                  7. Strongly Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679189: Student CenterVideo: The interviewee had good pacing, with no awkward pauses  \
# 0                                            6. Agree
# 1                                         2. Disagree
# 2                                            6. Agree
# 3                                         2. Disagree
# 4                                   5. Somewhat Agree
# ..                                                ...
# 57                                           6. Agree
# 58                                  5. Somewhat Agree
# 59                                           6. Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679191: \n\nStudent CenterVideo: Did you notice anything out of place, odd, or distracting in the session?\n\n  \
# 0                                         Not really.
# 1                        No i didn't notice anything.
# 2   The speaker did much less eye contact but just...
# 3   At times it didn’t feel the interviewee was be...
# 4                 I haven't noticed anything too odd.
# ..                                                ...
# 57                                                NaN
# 58  No, I did not notice anything out of place, od...
# 59   No I did not notice anything odd or distracting
# 60  No, seemed like a typical interview - nothing ...
# 61  He says "um" sometimes, which is slightly dist...
#
#    8679313: CODA Video: The interviewee made sufficient eye contact  \
# 0                                         2. Disagree
# 1                                3. Somewhat Disagree
# 2                                         2. Disagree
# 3                                   5. Somewhat Agree
# 4                                   5. Somewhat Agree
# ..                                                ...
# 57                                           6. Agree
# 58                                  5. Somewhat Agree
# 59                                           6. Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679303: CODA Video: The interviewee gave specific and detailed answers  \
# 0                                3. Somewhat Disagree
# 1                                         2. Disagree
# 2                                            6. Agree
# 3                                   5. Somewhat Agree
# 4                                          4. Neutral
# ..                                                ...
# 57                                  7. Strongly Agree
# 58                                           6. Agree
# 59                                  7. Strongly Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679305: CODA Video: The interviewee's answers were relevant and non-contradictory  \
# 0                                         2. Disagree
# 1                                3. Somewhat Disagree
# 2                                            6. Agree
# 3                                            6. Agree
# 4                                          4. Neutral
# ..                                                ...
# 57                                  7. Strongly Agree
# 58                                         4. Neutral
# 59                                           6. Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679307: CODA Video: The interviewee was engaged in the conversation  \
# 0                                         2. Disagree
# 1                                   5. Somewhat Agree
# 2                                          4. Neutral
# 3                                   5. Somewhat Agree
# 4                                   5. Somewhat Agree
# ..                                                ...
# 57                                           6. Agree
# 58                                           6. Agree
# 59                                  7. Strongly Agree
# 60                                           6. Agree
# 61                                           6. Agree
#
#    8679309: CODA Video: The interviewee had good pacing, with no awkward pauses  \
# 0                                         2. Disagree
# 1                                            6. Agree
# 2                                            6. Agree
# 3                                   5. Somewhat Agree
# 4                                   5. Somewhat Agree
# ..                                                ...
# 57                                  5. Somewhat Agree
# 58                                  5. Somewhat Agree
# 59                                  7. Strongly Agree
# 60                                  5. Somewhat Agree
# 61                                           6. Agree
#
#    8679311: Student Center and CODA Videos: Did you notice anything out of place, odd, or distracting in either/both of the sessions?
# 0   He was awkwardly pausing and swiveling around ...
# 1           no i didn't notice anything out of place.
# 2                                                 NaN
# 3                         nothing odd or distracting
# 4                                                  No
# ..                                                ...
# 57                                                NaN
# 58  No, I did not notice anything out of place, od...
# 59  nothing was distracting or out of place in eit...
# 60  No, seemed like a typical interview - nothing ...
# 61  He stumbled slightly in the CODA Video session...
#
# [62 rows x 12 columns]

# %%
#find nan, replace with ''
df[df.isna().any(axis=1)]
df.fillna('', inplace=True)
df2[df2.isna().any(axis=1)]
df2.fillna('', inplace=True)

# %%
#convert string to int answers
def string_to_int(x):
    if len(x) > 0 and x[0].isnumeric():
        return int(x[0])
    return x
df = df.applymap(string_to_int)
df2 = df2.applymap(string_to_int)

# %%
#split columns
eddf = df[df.columns[:6]]
fsdf = df[df.columns[6:]]
sc = df2[df2.columns[:6]]
coda = df2[df2.columns[6:]]

# %% [markdown]
# # Simple Mean detection, it was a lot better!

# %%
print("E Domain (With RA)")
for col in eddf.columns[:-1]:
    print(f"{col.split(':')[-1]} Mean: {eddf[col].mean()}")

print("Free Speech (Without RA)")
for col in fsdf.columns[:-1]:
    print(f"{col.split(':')[-1]} Mean: {fsdf[col].mean()}")
    
print("student center (Without RA)")
for col in eddf.columns[:-1]:
    print(f"{col.split(':')[-1]} Mean: {eddf[col].mean()}")

print("coda (with RA)")
for col in fsdf.columns[:-1]:
    print(f"{col.split(':')[-1]} Mean: {fsdf[col].mean()}")
# Out:
# E Domain (With RA)
#  The interviewee made sufficient eye contact Mean: 5.545454545454546
#  The interviewee gave specific and detailed answers Mean: 6.212121212121212
#  The interviewee's answers were relevant and non-contradictory Mean: 5.803030303030303
#  The interviewee was engaged in the conversation Mean: 6.03030303030303
#  The interviewee had good pacing, with no awkward pauses Mean: 5.7727272727272725
# Free Speech (Without RA)
#  The interviewee made sufficient eye contact Mean: 4.2727272727272725
#  The interviewee gave specific and detailed answers Mean: 4.954545454545454
#  The interviewee's answers were relevant and non-contradictory Mean: 4.818181818181818
#  The interviewee was engaged in the conversation Mean: 5.484848484848484
#  The interviewee had good pacing, with no awkward pauses Mean: 4.257575757575758
# student center (Without RA)
#  The interviewee made sufficient eye contact Mean: 5.545454545454546
#  The interviewee gave specific and detailed answers Mean: 6.212121212121212
#  The interviewee's answers were relevant and non-contradictory Mean: 5.803030303030303
#  The interviewee was engaged in the conversation Mean: 6.03030303030303
#  The interviewee had good pacing, with no awkward pauses Mean: 5.7727272727272725
# coda (with RA)
#  The interviewee made sufficient eye contact Mean: 4.2727272727272725
#  The interviewee gave specific and detailed answers Mean: 4.954545454545454
#  The interviewee's answers were relevant and non-contradictory Mean: 4.818181818181818
#  The interviewee was engaged in the conversation Mean: 5.484848484848484
#  The interviewee had good pacing, with no awkward pauses Mean: 4.257575757575758

# %% [markdown]
# # More complex Summary Statistics

# %%
df.columns
# Out:
# Index(['8574369: Eminent Domain Video: The interviewee made sufficient eye contact',
#        '8574371: Eminent Domain Video: The interviewee gave specific and detailed answers',
#        '8574373: Eminent Domain Video: The interviewee's answers were relevant and non-contradictory',
#        '8574375: Eminent Domain Video: The interviewee was engaged in the conversation',
#        '8574381: Eminent Domain Video: The interviewee had good pacing, with no awkward pauses',
#        '8574383: Eminent Domain Video: Did you notice anything out of place, odd, or distracting in the session?',
#        '8574705: Free Speech Video: The interviewee made sufficient eye contact',
#        '8574707: Free Speech Video: The interviewee gave specific and detailed answers',
#        '8574713: Free Speech Video: The interviewee's answers were relevant and non-contradictory',
#        '8574715: Free Speech Video: The interviewee was engaged in the conversation',
#        '8574717: Free Speech Video: The interviewee had good pacing, with no awkward pauses',
#        '8574719: Free Speech and Eminent Domain Videos: Did you notice anything out of place, odd, or distracting in either/both of the sessions?'],
#       dtype='object')

# %%
for i, col in enumerate(df.columns[:5]):
    print(df[[col, df.columns[i+6]]].describe())
    print('\n\n\n\n')
# Out:
#        8574369: Eminent Domain Video: The interviewee made sufficient eye contact  \
# count                                          66.000000
# mean                                            5.545455
# std                                             1.069606
# min                                             3.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#        8574705: Free Speech Video: The interviewee made sufficient eye contact
# count                                          66.000000
# mean                                            4.272727
# std                                             1.420135
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             7.000000
#
#
#
#
#
#        8574371: Eminent Domain Video: The interviewee gave specific and detailed answers  \
# count                                          66.000000
# mean                                            6.212121
# std                                             0.813637
# min                                             3.000000
# 25%                                             6.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000
#
#        8574707: Free Speech Video: The interviewee gave specific and detailed answers
# count                                          66.000000
# mean                                            4.954545
# std                                             1.208073
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             6.000000
# max                                             7.000000
#
#
#
#
#
#        8574373: Eminent Domain Video: The interviewee's answers were relevant and non-contradictory  \
# count                                          66.000000
# mean                                            5.803030
# std                                             0.995678
# min                                             3.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#        8574713: Free Speech Video: The interviewee's answers were relevant and non-contradictory
# count                                          66.000000
# mean                                            4.818182
# std                                             1.287921
# min                                             2.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             6.000000
# max                                             7.000000
#
#
#
#
#
#        8574375: Eminent Domain Video: The interviewee was engaged in the conversation  \
# count                                          66.000000
# mean                                            6.030303
# std                                             0.960284
# min                                             3.000000
# 25%                                             6.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000
#
#        8574715: Free Speech Video: The interviewee was engaged in the conversation
# count                                          66.000000
# mean                                            5.484848
# std                                             0.980462
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#
#
#
#
#        8574381: Eminent Domain Video: The interviewee had good pacing, with no awkward pauses  \
# count                                          66.000000
# mean                                            5.772727
# std                                             1.160841
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000
#
#        8574717: Free Speech Video: The interviewee had good pacing, with no awkward pauses
# count                                          66.000000
# mean                                            4.257576
# std                                             1.481274
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             6.000000

# %%
for i, col in enumerate(df2.columns[:5]):
    print(df2[[col, df2.columns[i+6]]].describe())
    print('\n\n\n\n')
# Out:
#        8679193: Student CenterVideo: The interviewee made sufficient eye contact  \
# count                                          62.000000
# mean                                            5.419355
# std                                             1.312592
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#        8679313: CODA Video: The interviewee made sufficient eye contact
# count                                          62.000000
# mean                                            4.629032
# std                                             1.506640
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             5.000000
# 75%                                             6.000000
# max                                             7.000000
#
#
#
#
#
#        8679183: Student CenterVideo: The interviewee gave specific and detailed answers  \
# count                                          62.000000
# mean                                            6.225806
# std                                             0.930703
# min                                             3.000000
# 25%                                             6.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000
#
#        8679303: CODA Video: The interviewee gave specific and detailed answers
# count                                          62.000000
# mean                                            5.790323
# std                                             1.202962
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000
#
#
#
#
#
#        8679185: Student CenterVideo: The interviewee's answers were relevant and non-contradictory  \
# count                                          62.000000
# mean                                            6.032258
# std                                             1.007639
# min                                             2.000000
# 25%                                             6.000000
# 50%                                             6.000000
# 75%                                             7.000000
# max                                             7.000000
#
#        8679305: CODA Video: The interviewee's answers were relevant and non-contradictory
# count                                          62.000000
# mean                                            5.596774
# std                                             1.179882
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#
#
#
#
#        8679187: Student CenterVideo: The interviewee was engaged in the conversation  \
# count                                          62.000000
# mean                                            5.854839
# std                                             0.955515
# min                                             3.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#        8679307: CODA Video: The interviewee was engaged in the conversation
# count                                          62.000000
# mean                                            5.629032
# std                                             1.089952
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#
#
#
#
#        8679189: Student CenterVideo: The interviewee had good pacing, with no awkward pauses  \
# count                                          62.000000
# mean                                            5.580645
# std                                             1.124225
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#        8679309: CODA Video: The interviewee had good pacing, with no awkward pauses
# count                                          62.000000
# mean                                            5.129032
# std                                             1.180218
# min                                             2.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             6.000000
# max                                             7.000000

# %%
bplots = []
for i, col in enumerate(df.columns[:5]):
    fig, ax = plt.subplots()
    b = df.boxplot([col, df.columns[i+6]])
    ax.set_xticklabels(['Eminent Domain (With RA)','Free Speech (Without RA)'])
    ax.set_yticklabels(['', 'Strongly Disagree: 1', '2', '3', 'Neutral: 4', '5', '6', 'Strongly Agree: 7'])
    plt.title(col.split(': ')[-1])
    ax.grid(False)
    plt.savefig(col.split(': ')[-1] + '.png')
    plt.show()
# Out:
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
for i, col in enumerate(df.columns[:5]):
    #print(col)
    s, p = stats.ttest_ind(df[col], df[df.columns[i+6]])
    print(f"Question: {col.split(': ')[-1]} Statistic: {s} P Value: {p})")
# Out:
# Question: The interviewee made sufficient eye contact Statistic: 5.815755226069746 P Value: 4.434216389664779e-08)
# Question: The interviewee gave specific and detailed answers Statistic: 7.014394918519988 P Value: 1.13654406852462e-10)
# Question: The interviewee's answers were relevant and non-contradictory Statistic: 4.914834540193683 P Value: 2.6263943680774026e-06)
# Question: The interviewee was engaged in the conversation Statistic: 3.22889184926616 P Value: 0.0015734824245797203)
# Question: The interviewee had good pacing, with no awkward pauses Statistic: 6.540645591568797 P Value: 1.2794038252846018e-09)

# %%
bplots = []
for i, col in enumerate(df2.columns[:5]):
    fig, ax = plt.subplots()
    b = df2.boxplot([col, df2.columns[i+6]])
    ax.set_xticklabels(['SC (Without RA)','Coda (With RA)'])
    ax.set_yticklabels(['', 'Strongly Disagree: 1', '2', '3', 'Neutral: 4', '5', '6', 'Strongly Agree: 7'])
    plt.title(col.split(': ')[-1])
    ax.grid(False)
    plt.savefig(col.split(': ')[-1] + 'counter.png')
    plt.show()
# Out:
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
for i, col in enumerate(df2.columns[:5]):
    #print(col)
    s, p = stats.ttest_ind(df2[col], df2[df2.columns[i+6]])
    print(f"Question: {col.split(': ')[-1]} Statistic: {s} P Value: {p})")
# Out:
# Question: The interviewee made sufficient eye contact Statistic: 3.1142834924605833 P Value: 0.002298295547636236)
# Question: The interviewee gave specific and detailed answers Statistic: 2.254496022296388 P Value: 0.0259487856498233)
# Question: The interviewee's answers were relevant and non-contradictory Statistic: 2.209981848196382 P Value: 0.02897209976722018)
# Question: The interviewee was engaged in the conversation Statistic: 1.226644378338168 P Value: 0.2223183731170703)
# Question: The interviewee had good pacing, with no awkward pauses Statistic: 2.1816402407655118 P Value: 0.03105312084095277)

# %%
cols = list(df2.columns)
cols = cols[6:] + cols[:6] 
tdf = df2[cols]
tdf = tdf.set_axis(df.columns, axis=1)
tdf = pd.concat([df, tdf], axis=0, ignore_index=True)

# %%
bplots = []
for i, col in enumerate(tdf.columns[:5]):
    fig, ax = plt.subplots()
    b = tdf.boxplot([col, tdf.columns[i+6]])
    ax.set_xticklabels(['with RA','without ra'])
    ax.set_yticklabels(['', 'Strongly Disagree: 1', '2', '3', 'Neutral: 4', '5', '6', 'Strongly Agree: 7'])
    plt.title(col.split(': ')[-1])
    ax.grid(False)
    plt.savefig(col.split(': ')[-1] + ' both.png')
    plt.show()
# Out:
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
for i, col in enumerate(tdf.columns[:5]):
    #print(col)
    s, p = stats.ttest_ind(df[col], tdf[tdf.columns[i+6]])
    print(f"Question: {col.split(': ')[-1]} Statistic: {s} P Value: {p})")
# Out:
# Question: The interviewee made sufficient eye contact Statistic: 3.493132943265135 P Value: 0.000592523166973901)
# Question: The interviewee gave specific and detailed answers Statistic: 3.7693654920379505 P Value: 0.00021772801735269042)
# Question: The interviewee's answers were relevant and non-contradictory Statistic: 2.1631210802764516 P Value: 0.03176772588362938)
# Question: The interviewee was engaged in the conversation Statistic: 2.4789554046174582 P Value: 0.014038975619686178)
# Question: The interviewee had good pacing, with no awkward pauses Statistic: 4.194372299389737 P Value: 4.1766389547916486e-05)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df2
# Out:
# /home/anishthite/miniconda3/envs/simgan-cgp/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
#     8679193: Student CenterVideo: The interviewee made sufficient eye contact  \
# 0   6
# 1   3
# 2   2
# 3   5
# 4   6
# 5   6
# 6   5
# 7   3
# 8   6
# 9   6
# 10  3
# 11  5
# 12  6
# 13  5
# 14  4
# 15  6
# 16  6
# 17  6
# 18  6
# 19  6
# 20  5
# 21  6
# 22  2
# 23  3
# 24  5
# 25  7
# 26  3
# 27  5
# 28  2
# 29  7
# 30  7
# 31  6
# 32  6
# 33  7
# 34  7
# 35  7
# 36  6
# 37  6
# 38  6
# 39  6
# 40  5
# 41  6
# 42  6
# 43  5
# 44  5
# 45  6
# 46  6
# 47  6
# 48  3
# 49  5
# 50  6
# 51  6
# 52  6
# 53  7
# 54  6
# 55  6
# 56  5
# 57  6
# 58  6
# 59  7
# 60  6
# 61  6
#
#     8679183: Student CenterVideo: The interviewee gave specific and detailed answers  \
# 0   5
# 1   5
# 2   7
# 3   4
# 4   6
# 5   7
# 6   5
# 7   7
# 8   7
# 9   7
# 10  6
# 11  7
# 12  7
# 13  6
# 14  5
# 15  7
# 16  7
# 17  7
# 18  7
# 19  7
# 20  7
# 21  6
# 22  3
# 23  5
# 24  6
# 25  7
# 26  6
# 27  5
# 28  4
# 29  6
# 30  6
# 31  6
# 32  7
# 33  7
# 34  7
# 35  6
# 36  7
# 37  5
# 38  6
# 39  6
# 40  7
# 41  7
# 42  7
# 43  5
# 44  6
# 45  7
# 46  7
# 47  7
# 48  7
# 49  6
# 50  6
# 51  6
# 52  5
# 53  7
# 54  7
# 55  6
# 56  6
# 57  7
# 58  6
# 59  7
# 60  7
# 61  6
#
#     8679185: Student CenterVideo: The interviewee's answers were relevant and non-contradictory  \
# 0   6
# 1   2
# 2   6
# 3   3
# 4   5
# 5   7
# 6   5
# 7   7
# 8   7
# 9   7
# 10  6
# 11  6
# 12  7
# 13  6
# 14  5
# 15  7
# 16  7
# 17  7
# 18  7
# 19  7
# 20  7
# 21  6
# 22  5
# 23  5
# 24  6
# 25  7
# 26  6
# 27  5
# 28  6
# 29  7
# 30  6
# 31  6
# 32  5
# 33  7
# 34  6
# 35  6
# 36  6
# 37  6
# 38  6
# 39  6
# 40  5
# 41  7
# 42  7
# 43  5
# 44  6
# 45  7
# 46  7
# 47  6
# 48  6
# 49  5
# 50  7
# 51  6
# 52  7
# 53  6
# 54  6
# 55  4
# 56  6
# 57  7
# 58  5
# 59  7
# 60  6
# 61  6
#
#     8679187: Student CenterVideo: The interviewee was engaged in the conversation  \
# 0   6
# 1   5
# 2   5
# 3   5
# 4   5
# 5   7
# 6   5
# 7   4
# 8   7
# 9   7
# 10  5
# 11  7
# 12  6
# 13  6
# 14  3
# 15  7
# 16  7
# 17  7
# 18  7
# 19  6
# 20  6
# 21  6
# 22  5
# 23  4
# 24  6
# 25  7
# 26  5
# 27  5
# 28  6
# 29  6
# 30  6
# 31  6
# 32  7
# 33  7
# 34  7
# 35  6
# 36  6
# 37  5
# 38  6
# 39  6
# 40  6
# 41  7
# 42  6
# 43  5
# 44  6
# 45  7
# 46  6
# 47  5
# 48  6
# 49  6
# 50  6
# 51  3
# 52  6
# 53  6
# 54  6
# 55  4
# 56  6
# 57  6
# 58  6
# 59  7
# 60  6
# 61  6
#
#     8679189: Student CenterVideo: The interviewee had good pacing, with no awkward pauses  \
# 0   6
# 1   2
# 2   6
# 3   2
# 4   5
# 5   6
# 6   5
# 7   5
# 8   7
# 9   6
# 10  5
# 11  6
# 12  7
# 13  6
# 14  3
# 15  6
# 16  7
# 17  7
# 18  5
# 19  6
# 20  6
# 21  6
# 22  4
# 23  3
# 24  6
# 25  7
# 26  5
# 27  6
# 28  4
# 29  6
# 30  6
# 31  6
# 32  5
# 33  7
# 34  7
# 35  6
# 36  6
# 37  5
# 38  6
# 39  5
# 40  6
# 41  7
# 42  6
# 43  5
# 44  5
# 45  6
# 46  6
# 47  4
# 48  5
# 49  4
# 50  6
# 51  6
# 52  6
# 53  6
# 54  7
# 55  6
# 56  6
# 57  6
# 58  5
# 59  6
# 60  6
# 61  6
#
#                                                                                                                                                                                          8679191: \n\nStudent CenterVideo: Did you notice anything out of place, odd, or distracting in the session?\n\n  \
# 0   Not really.
# 1   No i didn't notice anything.
# 2   The speaker did much less eye contact but just constantlystared at the same direction as if he was thinking deeply, making me a bit distracted because that is not like a conversation
# 3   At times it didn’t feel the interviewee was being very natural in speech.
# 4   I haven't noticed anything too odd.
# 5   Nothing.
# 6
# 7   It's not conversational, the content sounds like prepared script.
# 8   No. The interviewee captured my attention continuously and was engaged in a good conversation.
# 9   Not ver much. Sometimes there was an awkward moment after the answer was complete but before the next question; the interviewee sometime would smile a bit awkwardly and this would take my attention away from the topic of the student center and towards the level of awkwardness.
# 10  I didn’t notice anything out of pace, odd or distracting
# 11  No, I did not notice anything out of place, odd, or distracting in the session.
# 12  I did not notice anything out of place throughout the video. The interviewee seemed engaged while giving engaged and detailed answers about the student center.
# 13  There was nothing out of place, odd or distracting in the session.
# 14  The interviewer look at something on the right when thinking about the answer. His hand gestures don't indicate he was engaging in the interview.
# 15  Nothing out of place or odd, but the glare on the interviewee's glasses when he moved occasionally was somewhat distracting.
# 16  The interviewee made a forced smile between the responses, indicating stress.
# 17  I couldn't notice anything out of place, odd, or distracting in the session.
# 18  Auntie Annes was mentioned twice\n\nThe interviewee changed topics several times and jumped around between responses for different questions.
# 19  Nothing extremely distracting. I did notice the chair twirling, but it's far less than previous videos.
# 20  Not really. All look normal to me.
# 21  No
# 22  The interviewee kept looking to their left, away from the camera which was a little distracting.
# 23  The speaker made awkward pauses at the end of his answers (seemed like the speaker was waiting for something) and not much enthusiasm. He was looking off to the right side at times.
# 24  The interviewee is sometimes looking at the top left.
# 25  No, I think it is perfect.
# 26  Same thing as last time, repeatedly looks to the left when talking.
# 27  Nothing special
# 28  Yes, the interviewee kept looking to the right side of the frame during the interview. His eyes also appeared to roll up on occasion. I don’t think this constitutes abnormal behavior but just worth pointing out.
# 29  No
# 30  I did not notice anything out of place or out of the ordinary during the session.
# 31  Some parts seem a little scripted, but otherwise seemed normal.
# 32  Not many out of place moments this video. He mainly had less hand gestures, but seemed more confident in what he was talking about. He also would repeat himself a few times.
# 33  No.
# 34  I didn't notice anything too distracting or out of place or odd in this session.
# 35  Nothing in particular caught my eye outside of maybe the reflection on the interviewee's glasses
# 36  No
# 37  I now know that this guy just looks down to the left when he thinks but it's still kinda weird, since we're hyper-analzying his mannerisms.\n\nPhase 2 of the student center was originally supposed to be finished this spring and now I'm sad that I won't get to see it :( also rip Auntie Anne's
# 38  No, I thought overall his answers were good and his hand movement seemed to be reduced from the earlier videos.
# 39  No
# 40  It looked like he kept looking at something next to or behind the camera.
# 41  No
# 42  Not particularly. Video was a little laggy and the background had a large file, but otherwise it seemed normal. Color scheme of the video was a weird greenish-grey.
# 43  When not speaking, he bites his lib. His eye contact is a little all over the place as he sometimes looks around the room.
# 44   No
# 45  There was a glint in his glasses, but I couldn't tell if it was just a light behind the camera or something else
# 46  Nothing appeared out of place in this one.
# 47  There is a console remote but no console behind the interviewee.
# 48  The answers were good but the interviewee tended to look away from the camera
# 49
# 50  The interviewee’s hand movements
# 51  He looked very bored in between questions.
# 52  comments below
# 53  The TV behind
# 54  No, I did not notice anything out of place.
# 55  I cannot remember. I was focused on the speaker.
# 56  There was a lot of information about the food places, and there was a glare in the glasses.
# 57
# 58  No, I did not notice anything out of place, odd, or distracting in the session.
# 59  No I did not notice anything odd or distracting
# 60  No, seemed like a typical interview - nothing out of the ordinary.
# 61  He says "um" sometimes, which is slightly distracting.
#
#     8679313: CODA Video: The interviewee made sufficient eye contact  \
# 0   2
# 1   3
# 2   2
# 3   5
# 4   5
# 5   3
# 6   4
# 7   2
# ...
# 14  I think the intereview video is great in general. One point is that he sometimes rotates the chair which makes him looks like he is not very engaged.
# 15  The only thing distracting was his hand movements. But also it does seem odd that he knew very specific facts like how many people the conference rooms hold.
# 16  The interviewee made a forced smile between the responses, indicating stress.
# 17  The interviewee seemed to be a bit less confident about this topic in that the amount of his attempts to roll his eyes or pause the talk happened quite a lot compared to the previous interview.
# 18  The interviewee seemed a little less focussed  on the questions and more concerned about his answers.
# 19  Just the slight chair twirling thing. But it wasn't too distracting. I think in all the videos I marked eye contact as an "Agree" because he does look away when he's thinking, but it's not out of the ordinary or distracting.
# 20  The interviewer has more movement (i.e., gestures, rotating the chair), compared to that in the "Student Center Video".
# 21  No
# 22  The interviewee's hand gestures were distracting, and they kept swiveling their chair a little bit a well, in addition to looking to their left.
# 23  CODA videos: more gesturing and emotion in his speech this time, which seemed more natural and dynamic. He did seem to misspeak and then correct himself more than in the Student Center video.
# 24  Too much hand gesture; usually making his seat rotating.
# 25  Although there are some pauses, I think it is normal in an interview.
# 26  Same thing about looking to the left all of the time.
# 27  He seems to try to remember what he wanted to say very hard.
# 28  Not particularly
# 29  No
# 30  I did not notice anything out of place or out of the ordinary during the session. There was less eye contact in this video.
# 31  His speaking in this video didn't seem as smooth.
# 32  He just seemed a little for distracted compared to the other videos.
# 33  No, I didn't notice anything out of place or odd in either of these videos.
# 34  Nothing too much out of place in this session but we can see more of the interviewee's body and hand language in this video which might be distracting in a sense but I think it's also useful in terms of more information.
# 35  Nothing in particular caught my eye outside of maybe the reflection on the interviewee's glasses
# 36  Yes
# 37  He restarted sentences a few times, still looking down to the left but he was speaking faster this time. Honestly, he was talking kind of too fast. Also, there was something reflected in his glasses that kept getting in the way of seeing his actual eyes, which may or may not have been there last time but I noticed it this time.
# 38  I didnt notice anything out of place or distracting in either of the sessions.
# 39  No
# 40  Nope
# 41  no
# 42  Nope.
# 43  He repeats his word choices. He also bites his lip alot and overuses hand gestures.
# 44  No
# 45  This one felt like it had more pauses, and it seemed like he spent more time trying to remember his answers.
# 46  Nothing appeared out of place here.
# 47  The glare in the glasses was a bit distracting for the CODA videos.
# 48  There was more eye contact this time which made it less distracting than the last video
# 49
# 50  The interviewer didn’t have flow in his answers
# 51  Not in the second one
# 52  Both sessions: The overall tint of the videos were green - a more balanced color treatment of the videos would have been better. As usual, a plain shirt on a more plain background would have been less distracting.
# 53  The files
# 54  It could be because of light, but there is something on his right side glasses
# 55  I didn't notice anything odd. "Odd" also depends on what exactly we're talking about. The monitor behind the speaker, the drawers, the books?
# 56  He just looked to the side a lot, which might be just thinking
# 57
# 58  No, I did not notice anything out of place, odd, or distracting in both sessions.
# 59  nothing was distracting or out of place in either session
# 60  No, seemed like a typical interview - nothing out of the ordinary.
# 61  He stumbled slightly in the CODA Video session, and he said "um" a couple of times in the Student Center video. However, those were only slightly distracting
